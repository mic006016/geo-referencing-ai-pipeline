# %% [markdown]
# <a href="https://colab.research.google.com/github/mic006016/geo-referencing-ai-pipeline/blob/main/GeoAI_YOLOv8_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ultralytics 라이브러리 설치
# !pip install ultralytics -q
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Setup complete ✅ (12 CPUs, 167.1 GB RAM, 46.7/235.7 GB disk)

# %%
import os
import shutil
import cv2
import glob

from ultralytics import YOLO

# %%
from google.colab import drive

# 1. 구글 드라이브 연결
drive.mount('/content/drive')

# 2. 드라이브의 zip 파일을 코랩의 로컬 가상 디스크(/content)로 복사
zip_path = "/content/drive/MyDrive/yolo_dataset.zip"
local_zip_path = "/content/yolo_dataset.zip"

print("데이터 복사 중...")
shutil.copy(zip_path, local_zip_path)
print("복사 완료!")

# 3. 로컬에서 압축 해제 (-q 옵션으로 출력 생략하여 브라우저 렉 방지)
# !unzip -q {local_zip_path} -d /content/yolo_dataset
print("압축 해제 완료!")
# Out:
# Mounted at /content/drive
# 데이터 복사 중...
# 복사 완료!
# 압축 해제 완료!

# %%
from ultralytics import YOLO

# 1. 모델 로드
model = YOLO('yolov8s.pt')

# 2. 전이 학습 시작
results = model.train(
    data='/content/yolo_dataset/dataset.yaml',
    epochs=50,
    imgsz=512,
    batch=64,
    device=0,              # 0번 GPU 사용
    workers=8,             # 데이터 로딩에 사용할 CPU 워커 수
    amp=True,              # 자동 혼합 정밀도 (연산 속도 가속)
    project='geo_ai',      # 결과물이 저장될 폴더명
    name='land_cover_v2',
    save=True,             # 매 에포크마다 가중치 저장
    patience=10,           # 10 에포크 동안 성능 향상이 없으면 조기 종료

    # v2: 색상 증강 옵션
    hsv_h=0.05,  # 색조(Hue) 변형 대폭 증가 (YOLOv8 기본값: 0.015)
    hsv_s=0.9,   # 채도(Saturation) 변형 증가 (YOLOv8 기본값: 0.7)
    hsv_v=0.8,   # 명도(Value) 변형 증가 (YOLOv8 기본값: 0.4)
    mosaic=0.0   # 모자이크 증강 off (주변 맥락 노이즈 차단)
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 97.5MB/s 0.2s
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolo_dataset/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.05, hsv_s=0.9, hsv_v=0.8, imgsz=512, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=land_cover_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=geo_ai, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/geo_ai/land_cover_v2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 43.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117983  ultralytics.nn.modules.head.Detect           [5, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,137,535 parameters, 11,137,519 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 139.5MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2483.9±1158.0 MB/s, size: 123.6 KB)
# train: Scanning /content/yolo_dataset/train/labels... 35688 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35688/35688 1.5Kit/s 24.3s
# train: New cache created: /content/yolo_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1356.3±935.3 MB/s, size: 104.4 KB)
# val: Scanning /content/yolo_dataset/val/labels... 4454 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4454/4454 895.8it/s 5.0s
# val: New cache created: /content/yolo_dataset/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/geo_ai/land_cover_v2/labels.jpg...
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/geo_ai/land_cover_v2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.97G      1.046       1.37        1.2        540        512: 100% ━━━━━━━━━━━━ 558/558 5.6it/s 1:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.1it/s 17.0s
#                    all       4454      64301      0.733        0.7      0.733      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.9G      0.951     0.9534      1.117        497        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.2s
#                    all       4454      64301      0.714      0.701      0.728      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      10.9G      1.009      1.003      1.157        523        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.1it/s 16.3s
#                    all       4454      64301      0.685      0.662      0.682      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      10.9G      1.012     0.9967      1.165        556        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.2s
#                    all       4454      64301      0.712      0.698      0.725      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      10.9G     0.9603     0.9319      1.139        501        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.2s
#                    all       4454      64301      0.747      0.716      0.749       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      10.9G     0.9306     0.8925      1.123        499        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.1s
#                    all       4454      64301      0.752      0.725      0.759      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      10.9G     0.9088     0.8677      1.112        435        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.1s
#                    all       4454      64301      0.764      0.742      0.775      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      10.9G     0.8949     0.8496      1.106        541        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.0s
#                    all       4454      64301      0.761      0.743      0.784      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      10.9G     0.8804     0.8319      1.096        501        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.9s
#                    all       4454      64301      0.772      0.751       0.79      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      10.9G     0.8709     0.8191      1.091        449        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.0s
#                    all       4454      64301      0.783      0.749      0.797      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      10.9G     0.8618     0.8074      1.085        485        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.0s
#                    all       4454      64301      0.788       0.76      0.804      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      10.9G     0.8546     0.7959       1.08        422        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 16.0s
#                    all       4454      64301      0.784      0.762      0.805      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      10.9G     0.8473     0.7894      1.076        399        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.793      0.766      0.811      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      10.9G     0.8418     0.7806      1.073        478        512: 100% ━━━━━━━━━━━━ 558/558 5.9it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.797      0.768      0.812      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.9G      0.833     0.7715      1.067        549        512: 100% ━━━━━━━━━━━━ 558/558 5.9it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.799      0.767      0.814      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      10.9G     0.8297     0.7634      1.067        452        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.803      0.771      0.821       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      10.9G      0.825     0.7582      1.062        394        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.804      0.774      0.821      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      10.9G     0.8217     0.7504      1.061        509        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.801      0.778      0.823      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.9G     0.8169     0.7447      1.059        375        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.808      0.775      0.826      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      10.9G     0.8132     0.7388      1.057        440        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.807       0.78      0.828       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      10.9G     0.8085     0.7334      1.057        440        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.807      0.782      0.829      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      10.9G      0.805     0.7283      1.052        430        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.809      0.781      0.831      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      10.9G     0.7999      0.721      1.049        507        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.808      0.784      0.831      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      10.9G     0.7959     0.7145      1.048        530        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301       0.81      0.787      0.831      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      10.9G     0.7924     0.7088      1.044        579        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.813      0.787      0.832      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      10.9G     0.7889     0.7027      1.041        419        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.814      0.787      0.833      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      10.9G     0.7863     0.6978       1.04        546        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.6s
#                    all       4454      64301      0.813      0.789      0.834       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.9G     0.7821     0.6913      1.038        470        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.814      0.788      0.834      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      10.9G     0.7799     0.6857      1.037        453        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.816      0.788      0.835      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      10.9G     0.7739     0.6806      1.034        556        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.816       0.79      0.836      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      10.9G     0.7722     0.6753      1.033        470        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.816      0.791      0.836      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      10.9G     0.7672     0.6672       1.03        542        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.818       0.79      0.837      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      10.9G      0.765     0.6613      1.027        500        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.818       0.79      0.837      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      10.9G     0.7608     0.6547      1.027        456        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.819      0.789      0.838      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      10.9G     0.7566     0.6481      1.023        535        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.819      0.791      0.838      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      10.9G     0.7532     0.6401      1.021        360        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301       0.82      0.791      0.838      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.9G     0.7507     0.6335      1.019        491        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.821      0.791      0.838      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      10.9G     0.7468     0.6281      1.018        514        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.4s
#                    all       4454      64301       0.82      0.791      0.839      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      10.9G     0.7401     0.6181      1.014        496        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.821      0.791      0.839      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.9G     0.7381     0.6131      1.013        467        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.821       0.79      0.839      0.688
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      10.9G     0.7346     0.6061      1.011        476        512: 100% ━━━━━━━━━━━━ 558/558 5.7it/s 1:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.8s
#                    all       4454      64301      0.821      0.792       0.84      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      10.9G     0.7302     0.6004      1.011        399        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.821      0.792       0.84      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      10.9G     0.7271     0.5895      1.007        385        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.823      0.792       0.84      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      10.9G     0.7231     0.5825      1.004        377        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.7s
#                    all       4454      64301      0.823      0.792      0.841       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      10.9G     0.7188     0.5755      1.001        420        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.823      0.793      0.841       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      10.9G     0.7167     0.5704      1.003        401        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.825      0.792      0.841      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      10.9G     0.7113     0.5612          1        547        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.825      0.793      0.841      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      10.9G     0.7083     0.5554     0.9979        476        512: 100% ━━━━━━━━━━━━ 558/558 5.9it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.825      0.793      0.842      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      10.9G     0.7036     0.5497     0.9944        453        512: 100% ━━━━━━━━━━━━ 558/558 5.8it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.2it/s 15.6s
#                    all       4454      64301      0.826      0.794      0.842      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      10.9G     0.7021     0.5436     0.9944        443        512: 100% ━━━━━━━━━━━━ 558/558 5.9it/s 1:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 2.3it/s 15.5s
#                    all       4454      64301      0.827      0.793      0.842      0.692
#
# 50 epochs completed in 1.565 hours.
# Optimizer stripped from /content/runs/detect/geo_ai/land_cover_v2/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/detect/geo_ai/land_cover_v2/weights/best.pt, 22.5MB
#
# Validating /content/runs/detect/geo_ai/land_cover_v2/weights/best.pt...
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Model summary (fused): 73 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.6it/s 22.6s
#                    all       4454      64301      0.827      0.793      0.842      0.692
#               Building       3032      24316      0.815      0.759      0.835       0.65
#             GreenHouse       2162      11273      0.782      0.834      0.844      0.699
#                   Road       1553       2277      0.852      0.836      0.864      0.748
#              RicePaddy       2671      13918      0.913      0.897       0.93      0.829
#                  Field       3268      12517      0.772      0.642      0.737      0.534
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /content/runs/detect/geo_ai/land_cover_v2

# %%
#3. 테스트셋 평가
metrics = model.val(
    data='/content/yolo_dataset/dataset.yaml',
    split='test',          # 훈련에 관여하지 않은 테스트 데이터 지정
    project='geo_ai',
    name='land_cover_v2_test'
)
# Out:
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Model summary (fused): 73 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2170.2±702.5 MB/s, size: 109.2 KB)
# val: Scanning /content/yolo_dataset/test/labels... 4465 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4465/4465 1.5Kit/s 3.0s
# val: New cache created: /content/yolo_dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 280/280 10.9it/s 25.8s
#                    all       4465      62734      0.834      0.789      0.842      0.693
#               Building       2971      22477      0.815       0.74       0.82      0.634
#             GreenHouse       2182      11392        0.8      0.831      0.843      0.701
#                   Road       1543       2249      0.876      0.845      0.892       0.78
#              RicePaddy       2803      14740      0.914      0.887      0.928      0.823
#                  Field       3216      11876      0.764       0.64      0.728      0.527
# Speed: 0.4ms preprocess, 0.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/runs/detect/geo_ai/land_cover_v2_test

# %%
from google.colab import files

# 1. geo_ai 폴더를 results_v1.zip으로 압축 (-q 옵션으로 로그 생략)
# !zip -r -q /content/results_v2.zip /content/runs/detect/geo_ai/land_cover_v2_test

print("✅ 압축 완료! PC로 다운로드를 시작합니다.")

# 2. 브라우저를 통해 내 로컬 PC로 다운로드
files.download('/content/results_v2.zip')
# Out:
# ✅ 압축 완료! PC로 다운로드를 시작합니다.
