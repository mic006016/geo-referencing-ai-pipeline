# %% [markdown]
# <a href="https://colab.research.google.com/github/mic006016/geo-referencing-ai-pipeline/blob/main/GeoAI_YOLOv8_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ultralytics 라이브러리 설치
# !pip install ultralytics -q
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Setup complete ✅ (12 CPUs, 167.1 GB RAM, 46.7/235.7 GB disk)

# %%
import os
import shutil
import cv2
import glob

from ultralytics import YOLO

# %%
from google.colab import drive

# 1. 구글 드라이브 연결
drive.mount('/content/drive')

# 2. 드라이브의 zip 파일을 코랩의 로컬 가상 디스크(/content)로 복사
zip_path = "/content/drive/MyDrive/yolo_dataset.zip"
local_zip_path = "/content/yolo_dataset.zip"

print("데이터 복사 중...")
shutil.copy(zip_path, local_zip_path)
print("복사 완료!")

# 3. 로컬에서 압축 해제 (-q 옵션으로 출력 생략하여 브라우저 렉 방지)
# !unzip -q {local_zip_path} -d /content/yolo_dataset
print("압축 해제 완료!")
# Out:
# Mounted at /content/drive
# 데이터 복사 중...
# 복사 완료!
# 압축 해제 완료!

# %%
from ultralytics import YOLO

# 1. 모델 로드
model = YOLO('yolov8s.pt')

# 2. 전이 학습 시작
results = model.train(
    data='/content/yolo_dataset/dataset.yaml',
    epochs=50,
    imgsz=1024,            # v3: 해상도 증가
    batch=64,
    device=0,              # 0번 GPU 사용
    workers=8,             # 데이터 로딩에 사용할 CPU 워커 수
    amp=True,              # 자동 혼합 정밀도 (연산 속도 가속)
    project='geo_ai',      # 결과물이 저장될 폴더명
    name='land_cover_v4',
    save=True,             # 매 에포크마다 가중치 저장
    patience=10,           # 10 에포크 동안 성능 향상이 없으면 조기 종료

    # 색상 증강
    hsv_h=0.05,  # 색조(Hue) 변형 대폭 증가 (YOLOv8 기본값: 0.015)
    hsv_s=0.9,   # 채도(Saturation) 변형 증가 (YOLOv8 기본값: 0.7)
    hsv_v=0.8,   # 명도(Value) 변형 증가 (YOLOv8 기본값: 0.4)
    mosaic=0.0   # 모자이크 증강 off (주변 맥락 노이즈 차단)
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 408.8MB/s 0.1s
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolo_dataset/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.05, hsv_s=0.9, hsv_v=0.8, imgsz=1024, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=land_cover_v4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=geo_ai, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/geo_ai/land_cover_v4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 119.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117983  ultralytics.nn.modules.head.Detect           [5, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,137,535 parameters, 11,137,519 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 243.4MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1978.9±1075.6 MB/s, size: 123.6 KB)
# train: Scanning /content/yolo_dataset/train/labels... 35688 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 35688/35688 1.5Kit/s 24.2s
# train: New cache created: /content/yolo_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 975.8±669.3 MB/s, size: 104.4 KB)
# val: Scanning /content/yolo_dataset/val/labels... 4454 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4454/4454 833.1it/s 5.3s
# val: New cache created: /content/yolo_dataset/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/geo_ai/land_cover_v4/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to /content/runs/detect/geo_ai/land_cover_v4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      33.1G      1.062      1.459      1.339        543       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 25.9s
#                    all       4454      64301      0.703      0.693      0.716      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      35.2G     0.9402      0.989      1.239        500       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 25.2s
#                    all       4454      64301      0.708      0.688      0.707      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      35.1G     0.9855      1.034      1.277        524       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 25.6s
#                    all       4454      64301      0.598      0.566      0.558      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      35.1G     0.9783      1.021      1.275        560       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 25
0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      33.8G     0.6971     0.6078      1.072        400       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.837      0.794      0.852      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      33.7G      0.694     0.5974      1.067        387       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.838      0.795      0.853      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      33.1G     0.6898     0.5913      1.063        378       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.838      0.795      0.853      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      34.1G     0.6847     0.5816      1.062        428       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.839      0.795      0.853      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      33.8G     0.6829     0.5759      1.061        404       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.841      0.795      0.854      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      33.7G     0.6782     0.5659      1.057        548       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.7s
#                    all       4454      64301      0.841      0.795      0.854      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      33.6G     0.6751     0.5606      1.056        480       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:52
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.6s
#                    all       4454      64301      0.841      0.796      0.855      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      33.6G     0.6709     0.5526      1.052        455       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.8s
#                    all       4454      64301       0.84      0.797      0.855      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      33.8G     0.6685     0.5467      1.051        443       1024: 100% ━━━━━━━━━━━━ 558/558 1.9it/s 4:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.4it/s 24.9s
#                    all       4454      64301      0.841      0.797      0.855      0.698
#
# 50 epochs completed in 4.403 hours.
# Optimizer stripped from /content/runs/detect/geo_ai/land_cover_v4/weights/last.pt, 22.6MB
# Optimizer stripped from /content/runs/detect/geo_ai/land_cover_v4/weights/best.pt, 22.6MB
#
# Validating /content/runs/detect/geo_ai/land_cover_v4/weights/best.pt...
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Model summary (fused): 73 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 1.2it/s 29.9s
#                    all       4454      64301      0.841      0.797      0.855      0.698
#               Building       3032      24316      0.847      0.758      0.857      0.685
#             GreenHouse       2162      11273      0.792      0.849      0.857      0.721
#                   Road       1553       2277      0.872      0.826      0.869      0.688
#              RicePaddy       2671      13918      0.913      0.899      0.939      0.839
#                  Field       3268      12517      0.782      0.654      0.755      0.556
# Speed: 0.3ms preprocess, 1.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/runs/detect/geo_ai/land_cover_v4

# %%
#3. 테스트셋 평가
metrics = model.val(
    data='/content/yolo_dataset/dataset.yaml',
    split='test',          # 훈련에 관여하지 않은 테스트 데이터 지정
    project='geo_ai',
    name='land_cover_v4_test'
)
# Out:
# Ultralytics 8.4.110 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Model summary (fused): 73 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2135.6±519.6 MB/s, size: 109.2 KB)
# val: Scanning /content/yolo_dataset/test/labels... 4465 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4465/4465 1.5Kit/s 3.1s
# val: New cache created: /content/yolo_dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 280/280 7.0it/s 40.0s
#                    all       4465      62734      0.843      0.798      0.856      0.698
#               Building       2971      22477      0.839      0.745      0.844       0.67
#             GreenHouse       2182      11392      0.796      0.838      0.854      0.722
#                   Road       1543       2249      0.888      0.854      0.894      0.715
#              RicePaddy       2803      14740      0.911      0.897      0.936      0.832
#                  Field       3216      11876      0.778      0.657       0.75      0.551
# Speed: 1.7ms preprocess, 2.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /content/runs/detect/geo_ai/land_cover_v4_test

# %%
from google.colab import files

# 1. geo_ai 폴더를 results_v1.zip으로 압축 (-q 옵션으로 로그 생략)
# !zip -r -q /content/results_v4.zip /content/runs/detect/geo_ai/land_cover_v4_test

print("✅ 압축 완료! PC로 다운로드를 시작합니다.")

# 2. 브라우저를 통해 내 로컬 PC로 다운로드
files.download('/content/results_v4.zip')
# Out:
# ✅ 압축 완료! PC로 다운로드를 시작합니다.
